# %%
from getData import *
from mysqlDB import *

a = sqlDB("localhost","root","","cars")
b = obtainData
f2 = open("links.txt","r")
for links in f2:
#     links.replace("\n","")
    data = b.get_data(links.replace("\n",""))
    data = data[0:-1]
#     print(data)
    if len(data) == 11:
        sql = """INSERT INTO car_details (Name,price,Milage,fuelType,engine_cc,maxPower,maxTorque,seats,engineDiscription,TransmissionType,cargoVolume) VALUES (%s, %s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
        a.execute(sql,data)
    elif len(data) == 12:
        sql = """INSERT INTO car_details (Name,price,Milage,fuelType,cityMilage,engine_cc,maxPower,maxTorque,seats,engineDiscription,TransmissionType,cargoVolume) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
        a.execute(sql,data)
        
#     print(data)
#     data = b.get_data(links)
# Out:
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# 1 record inserted.
# ...
